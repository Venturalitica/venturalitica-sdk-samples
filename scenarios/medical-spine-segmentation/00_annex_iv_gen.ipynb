# %% [markdown]
# # 🎯 Level 4: The Architect - Annex IV Generation\n\n**⏱️ Time**: 5 minutes  \n**🎓 Complexity**: 🔴 Advanced  \n**🎯 Goal**: Automatically draft a Technical Documentation (Annex IV) compliance file using your audit evidence.\n\n---\n\n## 📚 What You'll Learn\n\n- How to turn `trace.json` evidence into a legal document\n- How to use Local (Ollama) or Sovereign (ALIA) LLMs for privacy\n- Why "Doc = f(Code)" is the future of regulation\n\n💡 **Focus**: We are solving the "Documentation Bottleneck".

# %%
import venturalitica as vl
import json
from pathlib import Path

print("🚀 Medical Scenario: Annex IV Generator")

# 1. Load your Evidence (The 'Glass Box' you created in Level 3)
# In a real scenario, this would come from your CI/CD artifacts.
trace_path = Path(".venturalitica/trace_latest.json")

if not trace_path.exists():
    print("⚠️ Trace not found! Running a quick audit to generate it...")
    vl.quickstart('medical') # Bootstrapping evidence
else:
    print("✅ Evidence found. Ready to draft docs.")

# %% [markdown]
# ## Step 2: The Agentic Writer\n\nWe will now ask the `AnnexIV_Generator` to read your trace and draft the document.\nIt uses the **EU AI Act Template**.\n\n**Note**: If you don't have a local LLM running, this step might prompt you to configure one.

# %%
# 2. Generate the PDF/Markdown
# This command launches the UI Agent because generation is interactive.
# You typically do this via the Dashboard, but here is the programmatic trigger:

print("👉 To generate the document, run:")
print("   uv run venturalitica ui")
print("   Then navigate to 'Annex IV Generator' tab.")

# %% [markdown]
# ### 🇪🇸 Sovereign Option: ALIA\n\nIf you select **ALIA** in the UI, the system will use the Spanish-native 40B model.\nEnsure you have sufficient RAM (40GB+) or it will run slowly on CPU.
